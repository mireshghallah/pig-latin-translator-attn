# %%
import os
import pdb
import argparse
import pickle as pkl

from collections import defaultdict

import numpy as np
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt

from easydict import EasyDict

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable

# Local imports
import utils
import data_handler
from data_handler import *
import attn_vis

# %%
# Options/ Hyperparameters required to train and test the model
opts = EasyDict()

opts.n_epochs = 1000
opts.batch_size = 16
opts.learning_rate = 0.01
opts.lr_decay = 0.99
opts.hidden_layer_size = 20
opts.model_name = "attention_rnn"
opts.checkpoints_dir = "./checkpoints/"+opts.model_name 

TEST_SENTENCE = 'attention brings more insight to the model'
TEST_WORD_ATTENTION = "attention"

# %%
utils.create_dir_if_not_exists(opts.checkpoints_dir)

# %%
line_pairs, vocab_size, idx_dict = load_data()

# %%
# dividing the line pairs into 8:2, train and val split
num_lines = len(line_pairs)
num_train = int(0.8 * num_lines)
train_pairs, val_pairs = line_pairs[:num_train], line_pairs[num_train:]

# %%
train_dict = create_dict(train_pairs)
val_dict = create_dict(val_pairs)

# Study the structure of the created train_dict and val_dict variables

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, hidden_size, opts):
        super(Encoder, self).__init__()

        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        self.opts = opts

        self.embedding = nn.Embedding(vocab_size, hidden_size)
        self.gru = nn.GRUCell(hidden_size, hidden_size)

    def forward(self, inputs):
        """Forward pass of the encoder RNN.

        Arguments:
            inputs: Input token indexes across a batch for all time steps in the sequence. (batch_size x seq_len)

        Returns:
            annotations: The hidden states computed at each step of the input sequence. (batch_size x seq_len x hidden_size)
            hidden: The final hidden state of the encoder, for each sequence in a batch. (batch_size x hidden_size)
        """

        batch_size, seq_len = inputs.size()
        hidden = self.init_hidden(batch_size)

        encoded = self.embedding(inputs)  # batch_size x seq_len x hidden_size
        annotations = []

        for i in range(seq_len):
            x = encoded[:,i,:]  # Get the current time step, across the whole batch
            hidden = self.gru(x, hidden)
            annotations.append(hidden)

        annotations = torch.stack(annotations, dim=1)
        return annotations, hidden

    def init_hidden(self, bs):
        """Creates a tensor of zeros to represent the initial hidden states
        of a batch of sequences.

        Arguments:
            bs: The batch size for the initial hidden state.

        Returns:
            hidden: An initial hidden state of all zeros. (batch_size x hidden_size)
        """
        return Variable(torch.zeros(bs, self.hidden_size))


class Attention(nn.Module):
    def __init__(self, hidden_size):
        super(Attention, self).__init__()

        self.hidden_size = hidden_size

        # ------------
        # FILL THIS IN
        # ------------

        # Create a two layer fully-connected network. 
        # [[hidden_size*2 --> hidden_size], [ReLU], [hidden_size --> 1]]
        
        self.attention_network = nn.Sequential(nn.Linear(hidden_size*2, hidden_size), nn.ReLU(), nn.Linear(hidden_size, 1))

        self.softmax = nn.Softmax(dim=1)

    def forward(self, hidden, annotations):
        """The forward pass of the attention mechanism.

        Arguments:
            hidden: The current decoder hidden state. (batch_size x hidden_size)
            annotations: The encoder hidden states for each step of the input sequence. (batch_size x seq_len x hidden_size)

        Returns:
            output: Normalized attention weights for each encoder hidden state. (batch_size x seq_len x 1)

            The output must be a softmax weighting over the seq_len annotations.
        """

        batch_size, seq_len, hid_size = annotations.size()
        expanded_hidden = hidden.unsqueeze(1).expand_as(annotations)

        # ------------
        # FILL THIS IN
        # ------------

        # You are free to follow the code template below, or do it a different way,
        # as long as the output is correct.

        concat = torch.cat([expanded_hidden, annotations], 2)
        # reshaped_for_attention_net = ...
        attention_net_output = self.attention_network.forward(concat)
        # unnormalized_attention = ...  # Reshape attention net output to have dimension batch_size x seq_len x 1

        return self.softmax(attention_net_output)


class AttentionDecoder(nn.Module):
    def __init__(self, vocab_size, hidden_size):
        super(AttentionDecoder, self).__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(vocab_size, hidden_size)

        self.rnn = nn.GRUCell(input_size=hidden_size*2, hidden_size=hidden_size)
        self.attention = Attention(hidden_size=hidden_size)
        self.out = nn.Linear(hidden_size, vocab_size)

    def forward(self, x, h_prev, annotations):
        """Forward pass of the attention-based decoder RNN.

        Arguments:
            x: Input token indexes across a batch for a single time step. (batch_size x 1)
            h_prev: The hidden states from the previous step, across a batch. (batch_size x hidden_size)
            annotations: The encoder hidden states for each step of the input.
                         sequence. (batch_size x seq_len x hidden_size)

        Returns:
            output: Un-normalized scores for each token in the vocabulary, across a batch. (batch_size x vocab_size)
            h_new: The new hidden states, across a batch. (batch_size x hidden_size)
            attention_weights: The weights applied to the encoder annotations, across a batch. (batch_size x encoder_seq_len x 1)
        """
        embed = self.embedding(x)    # batch_size x 1 x hidden_size
        embed = embed.squeeze(1)     # batch_size x hidden_size

        # ------------
        # FILL THIS IN
        # ------------
        attention_weights = self.attention.forward(h_prev, annotations)
        context = torch.sum((attention_weights.expand_as(annotations))*annotations,dim=1)
        #print context.size()
        embed_and_context = torch.cat([embed,context], 1)
        h_new = self.rnn(embed_and_context, h_prev)
        output = self.out(h_new)
        return output, h_new, attention_weights

# %%
##########################################################################
### Setup: Create Encoder, Decoder Objects ###
##########################################################################
encoder = Encoder(vocab_size=vocab_size, hidden_size=opts.hidden_layer_size, opts= opts)
decoder = AttentionDecoder(vocab_size=vocab_size, hidden_size=opts.hidden_layer_size)

# %%
def train_model(train_dict, val_dict, idx_dict, encoder, decoder, opts):
    """Runs the main training loop; evaluates the model on the val set every epoch.
        * Prints training and val loss each epoch.
        * Prints qualitative translation results each epoch using TEST_SENTENCE

    Arguments:
        train_dict: The training word pairs, organized by source and target lengths.
        val_dict: The validation word pairs, organized by source and target lengths.
        idx_dict: Contains char-to-index and index-to-char mappings, and start & end token indexes.
        encoder: An encoder model to produce annotations for each step of the input sequence.
        decoder: A decoder model to generate output tokens.
        opts: The input arguments for hyper-parameters and others.
    """
    
    # Define your loss function and optimizers
    # ....
    criterion = nn.CrossEntropyLoss()
    params_enc=encoder.parameters()
    params_dec=decoder.parameters()
    optimizer = optim.Adam(list(params_enc)+list(params_dec), lr=opts.learning_rate) 
    
    start_token = idx_dict['start_token']
    end_token = idx_dict['end_token']
    char_to_index = idx_dict['char_to_index']

    loss_log = open(os.path.join(opts.checkpoints_dir, 'loss_log.txt'), 'w')

    best_val_loss = 1e6
    train_losses = []
    val_losses = []

    for epoch in range(opts.n_epochs):
        
        # decay the learning rate of the optimizer
        # ....
        optimizer.param_groups[0]['lr'] *= opts.lr_decay

        epoch_losses = []

        for key in train_dict:

            input_strings, target_strings = zip(*train_dict[key])
            
            # Make your input tensor and the target tensors
            # HINT : use the function string_to_index_list given in data_handler.py
            # input_tensors = ....
            # output_tensors = ....
            input_tensors = [data_handler.string_to_index_list(string, char_to_index, end_token) for string in input_strings]
            output_tensors = [data_handler.string_to_index_list(string, char_to_index, end_token) for string in target_strings]
            input_tensors = torch.LongTensor(input_tensors)
            output_tensors = torch.LongTensor(output_tensors)
            num_tensors = len(input_tensors)
            num_batches = int(np.ceil(num_tensors / float(opts.batch_size)))

            for i in range(num_batches):

                start = i * opts.batch_size
                end = start + opts.batch_size
                
                # Define inputs and targets for THIS batch, beginning at index 'start' to 'end'
                # inputs = ....
                # outputs = ....
                inputs = torch.LongTensor(input_tensors[start:end])
                outputs = torch.LongTensor(output_tensors[start:end])
                # The batch size may be different in each epoch
                BS = inputs.size(0)

                encoder_annotations, encoder_hidden = encoder.forward(inputs)

                # The last hidden state of the encoder becomes the first hidden state of the decoder
                # decoder_hidden = ....
                decoder_hidden = encoder_hidden
                # Define the first decoder input. This would essentially be the start_token
                # decoder_input = ....
                decoder_input = torch.LongTensor([start_token for i in range(BS)])
                decoder_input = torch.LongTensor(decoder_input.unsqueeze(1))
                loss = 0.0

                seq_len = outputs.size(1)  # Gets seq_len from BS x seq_len

                for i in range(seq_len):
                    decoder_output, decoder_hidden, attention_weights = decoder.forward(decoder_input, \
                                                                                        decoder_hidden, \
                                                                                        encoder_annotations)

                    current_target = outputs[:,i]
                    
                    # Calculate the cross entropy between the decoder distribution and Ground truth (current_target)
                    # loss += ....
                    loss += criterion(decoder_output, current_target.type(torch.LongTensor))
                    # Find out the most probable character (ni) from the softmax distribution produced
                    # ni = ....

                    decoder_input = torch.LongTensor(outputs[:,i].unsqueeze(1))

                loss /= float(seq_len)
                epoch_losses.append(loss.item())

                # Compute gradients
                loss.backward()

                # Update the parameters of the encoder and decoder
                optimizer.step()
                optimizer.zero_grad()
        train_loss = np.mean(epoch_losses)
        val_loss = evaluate(val_dict, encoder, decoder, idx_dict, criterion, opts)

        if val_loss < best_val_loss:
            utils.store_checkpoints(encoder, decoder, idx_dict, opts)
        
        attn_vis.visualize_attention(TEST_WORD_ATTENTION,
                                      encoder,
                                      decoder,
                                      idx_dict,
                                      opts,
                                      save=os.path.join(opts.checkpoints_dir,\
                                                        'train_attns/attn-epoch-{}.png'.format(epoch)))
        gen_string = find_pig_latin(TEST_SENTENCE, encoder, decoder, idx_dict, opts)
        
        #gen_string="hello"
        #val_loss=100
        #gen string, vall_loss, grad_Zore, gruencoder:encoder, opts encoder, autograd variable
        print("Epoch: {:3d} | Train loss: {:.3f} | Val loss: {:.3f} | Gen: {:20s}".format(epoch, train_loss, val_loss, gen_string))

        loss_log.write('{} {} {}\n'.format(epoch, train_loss, val_loss))
        loss_log.flush()

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        utils.store_loss_plots(train_losses, val_losses, opts)

# %%
def evaluate(data_dict, encoder, decoder, idx_dict, criterion, opts):
    """Evaluates the model on a held-out validation or test set. 
    This should be pretty straight-forward if you have figured out how to do the training correctly.
    From then, it's just copy and paste.

    Arguments:
        data_dict: The validation/test word pairs, organized by source and target lengths.
        encoder: An encoder model to produce annotations for each step of the input sequence.
        decoder: A decoder model to generate output tokens.
        idx_dict: Contains char-to-index and index-to-char mappings, and start & end token indexes.
        criterion: Used to compute the CrossEntropyLoss for each decoder output.
        opts: The command-line arguments.

    Returns:
        mean_loss: The average loss over all batches from data_dict.
    """

    start_token = idx_dict['start_token']
    end_token = idx_dict['end_token']
    char_to_index = idx_dict['char_to_index']

    losses = []

    for key in data_dict:

        input_strings, target_strings = zip(*data_dict[key])
        # Make your input tensor and the target tensors
        # HINT : use the function string_to_index_list given in data_handler.py
        # input_tensors = ....
        # output_tensors = ....
        input_tensors = [data_handler.string_to_index_list(string, char_to_index, end_token) for string in input_strings]
        output_tensors = [data_handler.string_to_index_list(string, char_to_index, end_token) for string in target_strings]
        input_tensors = torch.LongTensor(input_tensors)
        output_tensors = torch.LongTensor(output_tensors)
        num_tensors = len(input_tensors)
        num_batches = int(np.ceil(num_tensors / float(opts.batch_size)))

        for i in range(num_batches):

            start = i * opts.batch_size
            end = start + opts.batch_size

            # Define inputs and targets for THIS batch, beginning at index 'start' to 'end'
            # inputs = ....
            # outputs = ....
            inputs = torch.LongTensor(input_tensors[start:end])
            outputs = torch.LongTensor(output_tensors[start:end])
            # The batch size may be different in each epoch
            BS = inputs.size(0)

            encoder_annotations, encoder_hidden = encoder.forward(inputs)
            
            # The last hidden state of the encoder becomes the first hidden state of the decoder
            # decoder_hidden = ....
            decoder_hidden = encoder_hidden
            
            # Define the first decoder input. This would essentially be the start_token
            # decoder_input = ....
            decoder_input = torch.LongTensor([start_token for i in range(BS)])
            decoder_input = decoder_input.unsqueeze(1)
            
            loss = 0.0

            seq_len = outputs.size(1)  # Gets seq_len from BS x seq_len

            for i in range(seq_len):
                decoder_output, decoder_hidden, attention_weights = decoder.forward(decoder_input,\
                                                                                    decoder_hidden,\
                                                                                    encoder_annotations)

                current_target = outputs[:,i]

                # Calculate the cross entropy between the decoder distribution and Ground truth (current_target)
                # loss += ....
                loss += criterion(decoder_output, current_target.type(torch.LongTensor))
                # Find out the most probable character (ni) from the softmax distribution produced
                # ni = ....
                decoder_output=torch.softmax(decoder_output.float(),1)
                _, indices = torch.max(decoder_output, 1)
                # Update decoder_input at the next time step to be this time-step's target 
                # decoder_input = ....
                decoder_input = outputs[:,i].unsqueeze(1)
            loss /= float(seq_len)
            losses.append(loss.item())

    mean_loss = np.mean(losses)

    return mean_loss

# %%
def find_pig_latin(sentence, encoder, decoder, idx_dict, opts):
    """Translates a sentence from English to Pig-Latin, by splitting the sentence into
    words (whitespace-separated), running the encoder-decoder model to translate each
    word independently, and then stitching the words back together with spaces between them.
    """
    return ' '.join([translate(word, encoder, decoder, idx_dict, opts) for word in sentence.split()])


def translate(input_string, encoder, decoder, idx_dict, opts):
    """Translates a given string from English to Pig-Latin.
    Not much to do here as well. Follows basically the same structure as that of the function evaluate.
    """

    char_to_index = idx_dict['char_to_index']
    index_to_char = idx_dict['index_to_char']
    start_token = idx_dict['start_token']
    end_token = idx_dict['end_token']

    max_generated_chars = 20
    gen_string = ''

    # convert given string to an array of indexes
    # HINT: use the function string_to_index_list provided in data_handler
    # indexes = ....
    indexes = data_handler.string_to_index_list(input_string, char_to_index, end_token)
    indexes =(torch.LongTensor(indexes))
    indexes =indexes.unsqueeze(0)
    encoder_annotations, encoder_last_hidden = encoder.forward(indexes)

    # The last hidden state of the encoder becomes the first hidden state of the decoder
    # decoder_hidden = ....
    decoder_hidden = encoder_last_hidden
    # Define the first decoder input. This would essentially be the start_token
    # decoder_input = ....
    decoder_input = torch.LongTensor([start_token for i in range(1)])
    
    decoder_input=decoder_input.unsqueeze(1)
    for i in range(max_generated_chars):
        decoder_output, decoder_hidden, attention_weights = decoder.forward(decoder_input,\
                                                                            decoder_hidden,\
                                                                            encoder_annotations)
    
        # Calculate the cross entropy between the decoder distribution and Ground truth (current_target)
        # loss += ....
        _, indices = torch.max(decoder_output, 1)
        ni=indices.unsqueeze(1)
        #ni = index_to_char[indices[0][0].item()]
        # Find out the most probable character (ni) from the softmax distribution produced
        # ni = ....

        if ni == end_token:
            break
        else:
            gen_string += index_to_char[ni[0][0].item()]
            
            # update decoder_input at the next time step to be ni 
            decoder_input = ni

    return gen_string

# %%
try:
    train_model(train_dict, val_dict, idx_dict, encoder, decoder, opts)
except KeyboardInterrupt:
    print('Exiting early from training.')
# Out:
# Epoch:   0 | Train loss: 1.769 | Val loss: 1.463 | Gen: atintestay insingsay orororay ingstighthay ottay ontoleshay orderlay
# Epoch:   1 | Train loss: 1.121 | Val loss: 1.152 | Gen: attentineway ingshingway oreepay inshthithay omttay elay oderllalleway
# Epoch:   2 | Train loss: 0.770 | Val loss: 0.896 | Gen: attentinionway ingssblay oreay insighthay otay elay odellway
# Epoch:   3 | Train loss: 0.574 | Val loss: 0.663 | Gen: attentionway ingssbay oremay insighthay otay eatthay odelay
# Epoch:   4 | Train loss: 0.450 | Val loss: 0.661 | Gen: attentionway ingsbay oremay insighthway oottay eetthay odelmay
# Epoch:   5 | Train loss: 0.377 | Val loss: 0.431 | Gen: attentionway ingsbray oreway insighthay otay uwthay odelmay
# Epoch:   6 | Train loss: 0.290 | Val loss: 0.398 | Gen: attentionway ingsbray oreway insigtway otay elay odelway
# Epoch:   7 | Train loss: 0.295 | Val loss: 0.538 | Gen: attentionway ingsbay oreway insightway ofay elay odelay
# Epoch:   8 | Train loss: 0.294 | Val loss: 0.433 | Gen: attentionway ingsbray oremay insightway ottay etay odelmay
# Epoch:   9 | Train loss: 0.297 | Val loss: 0.375 | Gen: attentionway ingsbray oremay insightway oway eway odelmay
# Epoch:  10 | Train loss: 0.261 | Val loss: 0.343 | Gen: attentionway ingsbray oremay insightway ottay etthay odelmay
# Epoch:  11 | Train loss: 0.223 | Val loss: 0.411 | Gen: attentionway ingsbray oremay insightway ottay etthay odelmay
# Epoch:  12 | Train loss: 0.190 | Val loss: 0.245 | Gen: attentionway ingsbray oremay insightway otay etay odelmay
# Epoch:  13 | Train loss: 0.177 | Val loss: 0.341 | Gen: attentionway ingsbray oremay insightway otay etay odelmay
# Epoch:  14 | Train loss: 0.161 | Val loss: 0.250 | Gen: attentionway ingsbray oremay insightway otay etay odelmay
# Epoch:  15 | Train loss: 0.144 | Val loss: 0.239 | Gen: attentionway ingsbray oremay insightway otay etay odelmay
# Epoch:  16 | Train loss: 0.176 | Val loss: 0.368 | Gen: attentionway ingsway oremay insightway otay nthay odelmay
# Epoch:  17 | Train loss: 0.220 | Val loss: 0.345 | Gen: attentionway ingsbray oremay insightway otay usthay odelmay
# Epoch:  18 | Train loss: 0.165 | Val loss: 0.262 | Gen: attentionway ingbray oremay insightway otay ehthay odelmay
# Epoch:  19 | Train loss: 0.160 | Val loss: 0.295 | Gen: attentionway ingsbray oremay insightway otay etthay odelmay
# Epoch:  20 | Train loss: 0.161 | Val loss: 0.238 | Gen: attentionway ingsbray oremay insiihtway otay ethay odelmay
# Epoch:  21 | Train loss: 0.099 | Val loss: 0.206 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  22 | Train loss: 0.094 | Val loss: 0.237 | Gen: attentionway ingshay oremay insightway otay ethay odelmay
# Epoch:  23 | Train loss: 0.111 | Val loss: 0.238 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  24 | Train loss: 0.144 | Val loss: 0.215 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  25 | Train loss: 0.118 | Val loss: 0.171 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  26 | Train loss: 0.156 | Val loss: 0.319 | Gen: attentionway ingsbray oremay inshightltay otay ethay odelmay
# Epoch:  27 | Train loss: 0.165 | Val loss: 0.295 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  28 | Train loss: 0.119 | Val loss: 0.244 | Gen: attentionway ingsbray oremay insightay otay ethay odelmay
# Epoch:  29 | Train loss: 0.104 | Val loss: 0.194 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  30 | Train loss: 0.095 | Val loss: 0.173 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  31 | Train loss: 0.065 | Val loss: 0.239 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  32 | Train loss: 0.121 | Val loss: 0.244 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  33 | Train loss: 0.113 | Val loss: 0.163 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  34 | Train loss: 0.107 | Val loss: 0.243 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  35 | Train loss: 0.093 | Val loss: 0.125 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  36 | Train loss: 0.074 | Val loss: 0.191 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  37 | Train loss: 0.100 | Val loss: 0.121 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  38 | Train loss: 0.051 | Val loss: 0.093 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  39 | Train loss: 0.061 | Val loss: 0.243 | Gen: attentionway ingsbray oremay insightway otay ethay odelomay
# Epoch:  40 | Train loss: 0.077 | Val loss: 0.171 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  41 | Train loss: 0.059 | Val loss: 0.104 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  42 | Train loss: 0.039 | Val loss: 0.202 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  43 | Train loss: 0.067 | Val loss: 0.174 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  44 | Train loss: 0.057 | Val loss: 0.205 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  45 | Train loss: 0.136 | Val loss: 0.268 | Gen: atquntionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  46 | Train loss: 0.092 | Val loss: 0.147 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  47 | Train loss: 0.070 | Val loss: 0.126 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  48 | Train loss: 0.055 | Val loss: 0.103 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  49 | Train loss: 0.031 | Val loss: 0.082 | Gen: attentionway ingsbray oremay insighttway otay ethay odelmay
# Epoch:  50 | Train loss: 0.049 | Val loss: 0.123 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  51 | Train loss: 0.049 | Val loss: 0.177 | Gen: attentionway ingsbray oremay insighttway otay ethay odelmay
# Epoch:  52 | Train loss: 0.042 | Val loss: 0.099 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  53 | Train loss: 0.032 | Val loss: 0.200 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  54 | Train loss: 0.099 | Val loss: 0.123 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  55 | Train loss: 0.063 | Val loss: 0.199 | Gen: attentionway ingsbray oremay insightway ytay ethay odelmay
# Epoch:  56 | Train loss: 0.055 | Val loss: 0.097 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  57 | Train loss: 0.048 | Val loss: 0.112 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  58 | Train loss: 0.034 | Val loss: 0.091 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  59 | Train loss: 0.048 | Val loss: 0.229 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  60 | Train loss: 0.051 | Val loss: 0.101 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  61 | Train loss: 0.052 | Val loss: 0.123 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  62 | Train loss: 0.056 | Val loss: 0.097 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  63 | Train loss: 0.035 | Val loss: 0.080 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  64 | Train loss: 0.020 | Val loss: 0.066 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  65 | Train loss: 0.017 | Val loss: 0.105 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  66 | Train loss: 0.026 | Val loss: 0.193 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  67 | Train loss: 0.099 | Val loss: 0.325 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  68 | Train loss: 0.104 | Val loss: 0.119 | Gen: attentionway ingsbray oremay insightway ytay tthay odelmay
# Epoch:  69 | Train loss: 0.038 | Val loss: 0.070 | Gen: attentionway ingsbray oremay insiihttway otay ethay odelmay
# Epoch:  70 | Train loss: 0.023 | Val loss: 0.068 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  71 | Train loss: 0.019 | Val loss: 0.078 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  72 | Train loss: 0.018 | Val loss: 0.064 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  73 | Train loss: 0.015 | Val loss: 0.061 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  74 | Train loss: 0.073 | Val loss: 0.218 | Gen: attentionway ingssbray oremay insightway otay ethay odelmay
# Epoch:  75 | Train loss: 0.089 | Val loss: 0.192 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  76 | Train loss: 0.149 | Val loss: 0.246 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  77 | Train loss: 0.093 | Val loss: 0.124 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  78 | Train loss: 0.046 | Val loss: 0.099 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  79 | Train loss: 0.030 | Val loss: 0.093 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  80 | Train loss: 0.021 | Val loss: 0.090 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  81 | Train loss: 0.017 | Val loss: 0.082 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  82 | Train loss: 0.013 | Val loss: 0.083 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  83 | Train loss: 0.014 | Val loss: 0.093 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  84 | Train loss: 0.034 | Val loss: 0.091 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  85 | Train loss: 0.040 | Val loss: 0.103 | Gen: attentionway ingssbray oremay insightway otay etway odelmay
# Epoch:  86 | Train loss: 0.033 | Val loss: 0.077 | Gen: attentionway ingsbray oremay insightway otay etay odelmay
# Epoch:  87 | Train loss: 0.031 | Val loss: 0.080 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  88 | Train loss: 0.016 | Val loss: 0.076 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  89 | Train loss: 0.010 | Val loss: 0.071 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  90 | Train loss: 0.009 | Val loss: 0.075 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  91 | Train loss: 0.009 | Val loss: 0.066 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  92 | Train loss: 0.071 | Val loss: 0.257 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  93 | Train loss: 0.076 | Val loss: 0.091 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  94 | Train loss: 0.045 | Val loss: 0.090 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  95 | Train loss: 0.024 | Val loss: 0.067 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  96 | Train loss: 0.014 | Val loss: 0.064 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  97 | Train loss: 0.009 | Val loss: 0.076 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  98 | Train loss: 0.008 | Val loss: 0.061 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch:  99 | Train loss: 0.005 | Val loss: 0.053 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 100 | Train loss: 0.004 | Val loss: 0.052 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 101 | Train loss: 0.005 | Val loss: 0.058 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 102 | Train loss: 0.015 | Val loss: 0.248 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 103 | Train loss: 0.066 | Val loss: 0.164 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 104 | Train loss: 0.068 | Val loss: 0.103 | Gen: attentionway ingsbray oremay insighttway otay etay odelmay
# Epoch: 105 | Train loss: 0.055 | Val loss: 0.113 | Gen: attentionway ingssbray oremay insightway otay ethay odelmay
# Epoch: 106 | Train loss: 0.027 | Val loss: 0.068 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 107 | Train loss: 0.015 | Val loss: 0.062 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 108 | Train loss: 0.012 | Val loss: 0.052 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 109 | Train loss: 0.009 | Val loss: 0.054 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 110 | Train loss: 0.005 | Val loss: 0.055 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 111 | Train loss: 0.004 | Val loss: 0.057 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 112 | Train loss: 0.004 | Val loss: 0.053 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 113 | Train loss: 0.003 | Val loss: 0.052 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 114 | Train loss: 0.003 | Val loss: 0.050 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 115 | Train loss: 0.002 | Val loss: 0.047 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 116 | Train loss: 0.002 | Val loss: 0.050 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 117 | Train loss: 0.036 | Val loss: 0.147 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 118 | Train loss: 0.044 | Val loss: 0.116 | Gen: attentionway ingsbray oremay insightwaytwaytwaytw otay ethay odelmay
# Epoch: 119 | Train loss: 0.020 | Val loss: 0.064 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 120 | Train loss: 0.005 | Val loss: 0.055 | Gen: attentionway ingssbray oremay insightway otay ethay odelmay
# Epoch: 121 | Train loss: 0.004 | Val loss: 0.055 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 122 | Train loss: 0.002 | Val loss: 0.047 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 123 | Train loss: 0.002 | Val loss: 0.051 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 124 | Train loss: 0.002 | Val loss: 0.051 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Epoch: 125 | Train loss: 0.001 | Val loss: 0.050 | Gen: attentionway ingsbray oremay insightway otay ethay odelmay
# Exiting early from training.
